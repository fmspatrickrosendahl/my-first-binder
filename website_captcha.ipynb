# %%
import requests
import urllib.request
from urllib import urlretrieve
import urlparse
import time
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_4639/1057368963.py in <module>
#       1 import requests
#       2 import urllib.request
# ----> 3 from urllib import urlretrieve
#       4 import urlparse
#       5 import time
#
# ImportError: cannot import name 'urlretrieve' from 'urllib' (/srv/conda/envs/notebook/lib/python3.7/urllib/__init__.py)

# %%
url = 'https://www.interasia.cc/content/c_service/cargo_tracking.aspx?SiteID=1'

headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }

response = requests.get(url, headers, verify=False)
soup = BeautifulSoup(response.content, 'html.parser')
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.interasia.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
#print(soup.prettify())
captcha_img = soup.find(id = "ctl00_CPHContent_imgCode")
print(captcha_img)
captcha_img_src = urlparse.urljoin(url, captcha_img.get('src'))
print(captcha_img_src)
captcha_img_src = 'https://www.interasia.cc/WebTools/RandomCode.ashx?Code='
# Out:
# <img alt="Enter the Captcha" border="0" id="ctl00_CPHContent_imgCode" src="../../WebTools/RandomCode.ashx?Code="/>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4639/962880903.py in <module>
#       2 captcha_img = soup.find(id = "ctl00_CPHContent_imgCode")
#       3 print(captcha_img)
# ----> 4 captcha_img_src = urlparse.urljoin(url, captcha_img.get('src'))
#       5 print(captcha_img_src)
#       6 captcha_img_src = 'https://www.interasia.cc/WebTools/RandomCode.ashx?Code='
#
# NameError: name 'urlparse' is not defined

# %%
image = requests.get(captcha_img_src, headers, verify=False)
print(image)
soup = BeautifulSoup(response.content, 'html.parser')
# Out:
# <Response [200]>
# /srv/conda/envs/notebook/lib/python3.7/site-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.interasia.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
