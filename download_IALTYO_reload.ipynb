# %%
import shutil
import os

zip_name = os.path.join('download_IALTYO_reload' )
directory_name = 'IALTYO_reload'

#os.remove(zip_name + ".zip")

shutil.make_archive(zip_name, 'zip', directory_name)
# Out:
# '/home/jovyan/download_IALTYO_reload.zip'
