# %%
import requests
import time
from requests.compat import urljoin
from bs4 import BeautifulSoup
from PIL import Image
import io
import shutil

# %%
url = 'https://www.interasia.cc/content/c_service/cargo_tracking.aspx?SiteID=1'

headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }

response = requests.get(url, headers, verify=False)
soup = BeautifulSoup(response.content, 'html.parser')
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.interasia.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
#print(soup.prettify())
captcha_img = soup.find(id = "ctl00_CPHContent_imgCode")
print(captcha_img)
captcha_img_src = urljoin(url, captcha_img.get('src'))
print(captcha_img_src)
captcha_img_src = 'https://www.interasia.cc/WebTools/RandomCode.ashx?Code='
image = requests.get(captcha_img_src, headers, verify=False, stream=True)
image.raw.decode_content = True
# Out:
# <img alt="Enter the Captcha" border="0" id="ctl00_CPHContent_imgCode" src="../../WebTools/RandomCode.ashx?Code="/>
# https://www.interasia.cc/WebTools/RandomCode.ashx?Code=
# /srv/conda/envs/notebook/lib/python3.7/site-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.interasia.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
image = Image.open(io.BytesIO(image.raw.data))
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# /tmp/ipykernel_141/1203276477.py in <module>
# ----> 1 image = Image.open(io.BytesIO(image.raw.data))
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode, formats)
#    3029         warnings.warn(message)
#    3030     raise UnidentifiedImageError(
# -> 3031         "cannot identify image file %r" % (filename if filename else fp)
#    3032     )
#    3033
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x7fe31410bdd0>
