# %%
import requests
import time
from requests.compat import urljoin
from bs4 import BeautifulSoup
from PIL import Image
import io
import shutil
from datetime import datetime

# %%
url = 'http://api.sitcline.com/code/?randomStr=84741641417596157'

headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }

#response = requests.get(url, headers, verify=False)
#soup = BeautifulSoup(response.content, 'html.parser')

# %%
#print(soup.prettify())
#captcha_img = soup.find(id = "ctl00_CPHContent_imgCode")
#print(captcha_img)
#captcha_img_src = urljoin(url, captcha_img.get('src'))
#print(captcha_img_src)

captcha_img_src = 'http://api.sitcline.com/code/?randomStr=84741641417596157'
for i in range(100) :
    response = requests.get(captcha_img_src, headers, verify=False, stream=True)
    response.raw.decode_content = True
    image = Image.open(io.BytesIO(response.raw.data))
    display(image)
    image.save("data/sitc1_" + str(datetime.now()) + ".jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F289747D0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F28974710>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F289748D0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F28974410>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F289747D0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F289743D0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F28974C10>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F28974E10>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F28974B50>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F28974C90>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F28974690>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x40 at 0x7F6F28974AD0>
# ...
