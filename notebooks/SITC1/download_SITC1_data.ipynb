# %%
import shutil
import os

zip_name = os.path.join('download_SITC1_data' )
directory_name = 'data'

#os.remove(zip_name + ".zip")

shutil.make_archive(zip_name, 'zip', directory_name)
# Out:
# '/home/jovyan/notebooks/SITC1/download_SITC1_data.zip'
